# %% [markdown]
# ## MapReduce no sistema de arquivo local

# %%
#Importar o código mapper.py utilizando a interface ao lado

# %%
# Testar o Mapper no sistema de arquivos local

# %%
# !cat ./resources/demo1/animals.txt
# Out:
# wolf
# monkey
# giraffe
# capibara
# wolf
# elephant
# kangaroo
# lion
# giraffe
# giraffe
# giraffe
# wolf
# kangaroo
# wolf
# monkey
# lion
# lion
# monkey
# wolf
# wolf
# asdasd

# %%
# !cat ./resources/demo1/animals.txt | python resources/demo1/mapper1.py
# Out:
# wolf	1
# monkey	1
# giraffe	1
# capibara	1
# wolf	1
# elephant	1
# kangaroo	1
# lion	1
# giraffe	1
# giraffe	1
# giraffe	1
# wolf	1
# kangaroo	1
# wolf	1
# monkey	1
# lion	1
# lion	1
# monkey	1
# wolf	1
# wolf	1
# asdasd	1

# %%
# !cat ./resources/demo1/animals.txt | python resources/demo1/mapper1.py | python resources/demo1/reducer1.py
# Out:
# wolf	1
# monkey	1
# giraffe	1
# capibara	1
# wolf	1
# elephant	1
# kangaroo	1
# lion	1
# giraffe	3
# wolf	1
# kangaroo	1
# wolf	1
# monkey	1
# lion	2
# monkey	1
# wolf	2
# asdasd	1

# %%
# !cat ./resources/demo1/animals.txt | python resources/demo1/mapper1.py | sort -k1,1
# Out:
# asdasd	1
# capibara	1
# elephant	1
# giraffe	1
# giraffe	1
# giraffe	1
# giraffe	1
# kangaroo	1
# kangaroo	1
# lion	1
# lion	1
# lion	1
# monkey	1
# monkey	1
# monkey	1
# wolf	1
# wolf	1
# wolf	1
# wolf	1
# wolf	1
# wolf	1

# %%
# !cat ./resources/demo1/animals.txt | python resources/demo1/mapper1.py | sort -k1,1 | python resources/demo1/reducer1.py
# Out:
# elephant	1
# giraffe	2
# kangaroo	2
# lion	3
# monkey	2
# wolf	3
# zebra	1

# %%
# !cat ./resources/demo1/futbr.csv
# Out:
# ano,campeonato brasileiro, copa do brasil
# 1989,Vasco da Gama,Grêmio
# 1990,Corinthians,Flamengo
# 1991,Criciúma,Corinthians
# 1992,Flamengo,Internacional
# 1993,Palmeiras,Cruzeiro
# 1994,Palmeiras,Grêmio
# 1995,Botafogo,Corinthians
# 1996,Grêmio,Cruzeiro
# 1997,Vasco da Gama,Grêmio
# 1998,Corinthians,Palmeiras
# 1999,Corinthians,Juventude
# 2000,Vasco da Gama,Cruzeiro
# 2001,Atlético Paranaense,Grêmio
# 2002,Santos,Corinthians
# 2003,Cruzeiro,Cruzeiro
# 2004,Santos,Santo André
# 2005,Corinthians,Paulista
# 2006,São Paulo,Flamengo
# 2007,São Paulo,Fluminense
# 2008,São Paulo,Sport
# 2009,Flamengo,Corinthians
# 2010,Fluminense,Santos
# 2011,Corinthians,Vasco da Gama
# 2012,Fluminense,Palmeiras
# 2013,Cruzeiro,Flamengo
# 2014,Cruzeiro,Atlético Mineiro
# 2015,Corinthians,Palmeiras
# 2016,Palmeiras,Grêmio
# 2017,Corinthians,Cruzeiro
# 2018,Palmeiras,Cruzeiro

# %%
# !cat ./resources/demo1/futbr.csv | python resources/demo1/mapper1.py
# Out:
# ano,campeonato brasileiro, copa do brasil	1
# 1989,Vasco da Gama,Grêmio	1
# 1990,Corinthians,Flamengo	1
# 1991,Criciúma,Corinthians	1
# 1992,Flamengo,Internacional	1
# 1993,Palmeiras,Cruzeiro	1
# 1994,Palmeiras,Grêmio	1
# 1995,Botafogo,Corinthians	1
# 1996,Grêmio,Cruzeiro	1
# 1997,Vasco da Gama,Grêmio	1
# 1998,Corinthians,Palmeiras	1
# 1999,Corinthians,Juventude	1
# 2000,Vasco da Gama,Cruzeiro	1
# 2001,Atlético Paranaense,Grêmio	1
# 2002,Santos,Corinthians	1
# 2003,Cruzeiro,Cruzeiro	1
# 2004,Santos,Santo André	1
# 2005,Corinthians,Paulista	1
# 2006,São Paulo,Flamengo	1
# 2007,São Paulo,Fluminense	1
# 2008,São Paulo,Sport	1
# 2009,Flamengo,Corinthians	1
# 2010,Fluminense,Santos	1
# 2011,Corinthians,Vasco da Gama	1
# 2012,Fluminense,Palmeiras	1
# 2013,Cruzeiro,Flamengo	1
# 2014,Cruzeiro,Atlético Mineiro	1
# 2015,Corinthians,Palmeiras	1
# 2016,Palmeiras,Grêmio	1
# 2017,Corinthians,Cruzeiro	1
# 2018,Palmeiras,Cruzeiro	1

# %%
# !cat ./resources/demo1/futbr.csv | python resources/demo1/mapper2.py | sort -k1,1 | python resources/demo1/reducer1.py

# %%
# !cat ./resources/demo1/iot-temperature.csv | python resources/demo1/mapper2.py | sort -k1,1 | python resources/demo1/reducer1.py
# Out:
# 14.0	22
# 14.1	34
# 14.2	32
# 14.4	36
# 14.5	17
# 14.6	76
# 14.7	81
# 14.8	96
# 14.9	4
# 15.0	69
# 15.1	42
# 15.2	47
# 15.3	57
# 15.4	67
# 15.5	90
# 15.6	94
# 15.7	81
# 15.8	57
# 16.0	59
# 16.1	29
# 16.2	32
# 16.3	36
# 16.4	23
# 16.5	43
# 16.6	89
# 16.7	74
# 16.8	60
# 16.9	2
# 17.0	50
# 17.1	38
# 17.2	68
# 17.3	134
# 17.4	149
# 17.5	165
# 17.6	144
# 17.7	209
# 17.8	166
# 17.9	9
# 18.0	181
# 18.1	161
# 18.2	220
# 18.3	409
# 18.4	470
# 18.5	386
# 18.6	363
# 18.7	341
# 18.8	350
# 18.9	20
# 19.0	368
# 19.1	348
# 19.2	274
# 19.3	280
# 19.4	273
# 19.5	308
# 19.6	288
# 19.7	258
# 19.8	312
# 19.9	12
# 20.0	274
# 20.1	283
# 20.2	325
# 20.3	283
# 20.4	264
# 20.5	249
# 20.6	261
# 20.7	236
# 20.8	252
# 20.9	333
# 21.0	450
# 21.1	421
# 21.2	392
# 21.3	404
# 21.4	410
# 21.5	417
# 21.6	410
# 21.7	576
# 21.8	493
# 21.9	535
# 22.0	508
# 22.1	392
# 22.2	413
# 22.3	363
# 22.4	28
# 22.5	442
# 22.6	582
# 22.7	654
# 22.8	542
# 22.9	545
# 23.0	629
# 23.1	685
# 23.2	687
# 23.3	716
# 23.4	685
# 23.5	844
# ...

# %%
# !cat ./resources/demo1/iot-temperature.csv | python resources/demo1/mapper3.py 4 | sort -k1,1 | python resources/demo1/reducer1.py
# Out:
# 14.0	22
# 14.1	34
# 14.2	32
# 14.4	36
# 14.5	17
# 14.6	76
# 14.7	81
# 14.8	96
# 14.9	4
# 15.0	69
# 15.1	42
# 15.2	47
# 15.3	57
# 15.4	67
# 15.5	90
# 15.6	94
# 15.7	81
# 15.8	57
# 16.0	59
# 16.1	29
# 16.2	32
# 16.3	36
# 16.4	23
# 16.5	43
# 16.6	89
# 16.7	74
# 16.8	60
# 16.9	2
# 17.0	50
# 17.1	38
# 17.2	68
# 17.3	134
# 17.4	149
# 17.5	165
# 17.6	144
# 17.7	209
# 17.8	166
# 17.9	9
# 18.0	181
# 18.1	161
# 18.2	220
# 18.3	409
# 18.4	470
# 18.5	386
# 18.6	363
# 18.7	341
# 18.8	350
# 18.9	20
# 19.0	368
# 19.1	348
# 19.2	274
# 19.3	280
# 19.4	273
# 19.5	308
# 19.6	288
# 19.7	258
# 19.8	312
# 19.9	12
# 20.0	274
# 20.1	283
# 20.2	325
# 20.3	283
# 20.4	264
# 20.5	249
# 20.6	261
# 20.7	236
# 20.8	252
# 20.9	333
# 21.0	450
# 21.1	421
# 21.2	392
# 21.3	404
# 21.4	410
# 21.5	417
# 21.6	410
# 21.7	576
# 21.8	493
# 21.9	535
# 22.0	508
# 22.1	392
# 22.2	413
# 22.3	363
# 22.4	28
# 22.5	442
# 22.6	582
# 22.7	654
# 22.8	542
# 22.9	545
# 23.0	629
# 23.1	685
# 23.2	687
# 23.3	716
# 23.4	685
# 23.5	844
# ...
